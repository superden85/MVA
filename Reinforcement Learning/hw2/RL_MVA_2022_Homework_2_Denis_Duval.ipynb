# %% [markdown]
# # MVA - Homework 2 - Reinforcement Learning (2022/2023)
#
# **Name:** DUVAL Denis
#
# **Email:**   denis.duval13@gmail.com

# %% [markdown]
# ## Instructions
#
# * The deadline is **December 16 (2022) at 11:59 pm (Paris time).**
#
# * By doing this homework you agree to the late day policy, collaboration and misconduct rules reported on [Piazza](https://piazza.com/class/l4y5ubadwj64mb?cid=6).
#
# * **Mysterious or unsupported answers will not receive full credit**. A correct answer, unsupported by calculations, explanation, or algebraic work will receive no credit; an incorrect answer supported by substantially correct calculations and explanations might still receive partial credit.
#
# * Answers should be provided in **English**.

# %% [markdown]
# # Colab setup

# %%
from IPython import get_ipython

if 'google.colab' in str(get_ipython()):
  # install rlberry library
  # !pip install git+https://github.com/rlberry-py/rlberry.git@mva2021#egg=rlberry[default] > /dev/null 2>&1

  # pytorch
  # !pip install torch > /dev/null 2>&1

  # install ffmpeg-python for saving videos
  # !pip install ffmpeg-python > /dev/null 2>&1

  # packages required to show video
  # !pip install pyvirtualdisplay > /dev/null 2>&1
  # !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

  print("Libraries installed, please restart the runtime!")
# Out:
# Libraries installed, please restart the runtime!

# %%
# !apt-get update
# !apt-get install xvfb
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.13).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.

# %%
# Create directory for saving videos
# !mkdir videos > /dev/null 2>&1

# Initialize display and import function to show videos
import rlberry.colab_utils.display_setup
from rlberry.colab_utils.display_setup import show_video

# %%
# !pip install gym==0.22
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym==0.22 in /usr/local/lib/python3.8/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22) (1.21.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22) (1.5.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /usr/local/lib/python3.8/dist-packages (from gym==0.22) (4.13.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from gym==0.22) (0.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.10.0->gym==0.22) (3.11.0)

# %%
# Useful imports
import gym
import torch
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from gym.wrappers import Monitor
from rlberry.agents import Agent
from rlberry.manager import AgentManager, plot_writer_data

import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical

# torch device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# [INFO] OpenGL_accelerate module loaded
# [INFO] Using accelerated ArrayDatatype
# [INFO] Generating grammar tables from /usr/lib/python3.8/lib2to3/Grammar.txt
# [INFO] Generating grammar tables from /usr/lib/python3.8/lib2to3/PatternGrammar.txt
# [INFO] NumExpr defaulting to 2 threads.

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Environment
# In the coding exercises, you will use the CartPole environment from [Gym](https://gym.openai.com/) library. The cells below show how to interact with this MDP and how to visualize it.

# %%
def get_env():
  """Creates an instance of a CartPole-v0 environment."""
  return gym.make('CartPole-v0')

def render_policy(env, agent):
  env = deepcopy(env)
  env = Monitor(env, './videos', force=True, video_callable=lambda episode: True)
  for episode in range(1):
    done = False
    state = env.reset()
    env.render()
    while not done:
        action = agent.select_action(state, evaluation=True)
        state, reward, done, info = env.step(action)
        env.render()
    env.close()
    show_video()

# %% [markdown]
# ## Running experiments with `rlberry`
# In order to compare different algorithms, you'll need to run experiments several times and plot the results. For that, we use the [rlberry](https://github.com/rlberry-py/rlberry) library here.
# The code below gives a quick introduction to what you will need from this library, but you can also check its documentation [here](https://rlberry.readthedocs.io/en/latest/).
#
# Basically, all you have to do is to write your agents using the `rlberry.agents.Agent` interface, and `rlberry` provides an `AgentManger` class that allows you to run your agents in parallel and plot the results.

# %%
from rlberry.agents import Agent

class MyAgent(Agent):
  name = "MyAgent"
  def __init__(self, env, param1, param2, **kwargs):
    """
    The base class (Agent) initializes:
      self.env : instance of the environment used for training (in fit() method)
      self.eval_env : instance of the environment used for evaluation (in eval() method)
      self.rng : random number generator (https://numpy.org/doc/stable/reference/random/generator.html)
      self.writer : use self.writer.add_scalar(tag, value, global_step) to log training data
    
    For reproducibility, use ONLY self.rng if you need random numbers in you agent!
    To be able to visualize plots with AgentManager, log data using self.writer (see below)
    """
    Agent.__init__(self, env, **kwargs)
    self.param1 = param1
    self.param2 = param2
    self.total_steps = 0
    self.total_episodes = 0

  def select_action(self, state, evaluation=False):
    """
    If evaluation=True, run evaluation policy (e.g., greedy with respect to Q)
    If evaluation=False, run exploration policy (e.g., epsilon greedy)
    """
    return self.env.action_space.sample()  # random action for this example

  def fit(self, budget):
    """budget = number of timesteps to train your agent"""
    state = self.env.reset()
    episode_reward = 0.0
    for tt in range(budget):
      self.total_steps += 1
      action = self.select_action(state, evaluation=False)
      next_state, reward, done, _ = self.env.step(action)
      episode_reward += reward

      # Log data
      self.writer.add_scalar('rewards', reward, global_step=self.total_steps)

      state = next_state 
      if done:
        self.total_episodes += 1
        # Log episode data
        self.writer.add_scalar('episode_rewards', episode_reward, global_step=self.total_steps)
        self.writer.add_scalar('episode', self.total_episodes, global_step=self.total_steps)

        state = self.env.reset()
        episode_reward = 0.0
        
  
  def eval(self, **kwargs):
    """
    Here, you can run Monte-Carlo policy evaluation 
    with self.eval_env and return the result.
    Returning zero for this example.
    """
    return 0.0

# %%
#
# Initialize and train a single instance of MyAgent
#
my_agent = MyAgent(
    env=(get_env, {}),       # tuple (constructor, kwargs)
    param1=10,               # extra params your agent might need
    param2=15)
# train the agent for 100 timesteps
my_agent.fit(100)
# pandas DataFrame containing data stored with my_agent.writer.add_scalar(tag, value, global_step)
print(my_agent.writer.data)

#
# Run several instances of MyAgent in parallel and plot the results
#
manager_kwargs = dict(
    agent_class=MyAgent,
    train_env=(get_env, dict()),
    eval_env=(get_env, dict()),
    fit_budget=100,                    # Number of total timesteps
    n_fit=2,                           # Number of agent instances to fit
    parallelization='thread',          # Use 'thread' in the notebook!
    seed=456,                          # Seed
    default_writer_kwargs=dict(maxlen=None,log_interval=10),
)
my_agent_manager = AgentManager(
    init_kwargs=dict(param1=10, param2=20),
    agent_name='MyAgent',
    **manager_kwargs
)
my_agent_manager.fit()   # Train 'n_fit' instances in parallel
# Out:
# INFO: Making new env: CartPole-v0
# /usr/local/lib/python3.8/dist-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# INFO: Making new env: CartPole-v0
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for MyAgent...
# INFO: Making new env: CartPole-v0
# /usr/local/lib/python3.8/dist-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
#         name              tag  value global_step
# 0    MyAgent          rewards    1.0           1
# 1    MyAgent          rewards    1.0           2
# 2    MyAgent          rewards    1.0           3
# 3    MyAgent          rewards    1.0           4
# 4    MyAgent          rewards    1.0           5
# ..       ...              ...    ...         ...
# 211  MyAgent  episode_rewards   15.0          80
# 212  MyAgent          episode    1.0          19
# 213  MyAgent          episode    2.0          50
# 214  MyAgent          episode    3.0          65
# 215  MyAgent          episode    4.0          80
#
# [216 rows x 4 columns]
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
# Plot the results
example_managers = []
example_managers.append(my_agent_manager)    # You could add more managers here, for other agents/parameters
_ = plot_writer_data(example_managers, tag='rewards', title='Instantaneous Rewards')
_ = plot_writer_data(example_managers, tag='episode_rewards', xtag='episode', title='Episode Rewards')
_ = plot_writer_data(example_managers, tag='episode_rewards', xtag='episode', title='Cumulative Episode Rewards', preprocess_func=np.cumsum)

# Render the policy of one of the trained agents
agent_instance = my_agent_manager.get_agent_instances()[0]
render_policy(agent_instance.eval_env, agent_instance)
# Out:
# INFO: Starting new video recorder writing to /content/videos/openaigym.video.0.1419.video000000.mp4
# INFO: Finished writing results. You can upload them to the scoreboard via gym.upload('/content/videos')
# <video alt="videos/openaigym.video.0.1419.video000000.mp4" autoplay
#                       loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %% [markdown]
# # Part 1: DQN
#
# The goal of this exercise is to compare different variants of Deep Q-Learning (a.k.a. DQN).
#
# **DQN.**
# Recall from the class the DQN aims to minimize the following loss function
# $$
#     L(\theta) = \mathbb{E}_{s,a,r,s' \sim \mathcal{D}} \left[
# \left(
#     r + \gamma \max_{a' \in\mathcal{A}} Q(s',a';\theta') - Q(s,a; \theta)
# \right)^2
#     \right ]
# $$
# where $\theta'$ is the parameter of the target network updated every $C$ iterations from $\theta$.

# %% [markdown]
# ## Question 1.1 (written)
#
# **(a)** The DQN objective resembles a classical supervised learning problem. Could you highlight the differences?
#
# **(b)** Could you describe the role of $C$ and the trade-off at play in choosing a good value for $C$?

# %% [markdown]
# *write your answer here*
#
# *   a) The main difference is that in classical supervised learning problem the dataset is fixed at the beginning and does not change during training. Furthermore, in DQN the dataset is modified with respect to the model because the samples in the dataset are collected while the model is trained. Also, the target model changes during training.
#
# *   b) The parameter $C$ controls the stability of the target of the model. When $C \rightarrow 1$, this is equivalent to not have any target because we update the target with the model at each step. So the target is varying much but the target has good chances to be a good one. Whereas when $C → ∞$ we almost never update the model so the target has low chances to be a good target however the model has more time to converge to it.

# %% [markdown]
# ## Question 2.2 (implementation)
#
# We would like to evaluate DQN with newer variants of DQN, namely Double DQN, Dueling DQN and Double Dueling DQN.
# In class we have seen the principle of DQN, please refer to the following paper for Double and Dueling DQN (https://arxiv.org/abs/1511.06581).
#
#
#
# The difference between DQN and Double DNQ is how the target network is built. In Double DQN we use the greedy action suggested by $Q(s,a; \boldsymbol{\theta})$ to evaluate the target (i.e., $\theta'$), see the appendix of https://arxiv.org/abs/1511.06581.
#
# In Dueling DQN, the Q function is estimated as
# $$
#     Q(s,a) = V(s) + A(s,a) - \frac{1}{|\mathcal{A}|} \sum_{a'} A(s,a')
# $$
# $V$ and $A$ share parameters.
# Dueling DQN can be implemented "standard" or "double".
#
#
# Starting from the provided code:
# - (code) Implement DQN and Double DQN. Use the network in the figure below **(top)**.
# - (code) Implement Dueling DQN and Dueling Double DQN. See the figure below **(bottom)** for the network with shared parameters.
# - Compare the performance of the algorithms.
#
#
# More precisely, you'll have to:
# * complete the code for the networks `QNet` and `DuelingQNet`;
# * compute the loss in the fit() method of `DQNAgent`
# * define the exploration and evaluation policy in the `select_action` method of `DQNAgent`

# %% [markdown]
# ![rlmva_homework2.png](data:image/png;base64,...)

# %%
class ReplayBuffer:
  def __init__(self, capacity, rng):
    """
    Parameters
    ----------
    capacity : int
      Maximum number of transitions
    rng : 
      instance of numpy's default_rng
    """
    self.capacity = capacity
    self.rng = rng  # random number generator
    self.memory = []
    self.position = 0

  def push(self, sample):
    """Saves a transition."""
    if len(self.memory) < self.capacity:
      self.memory.append(None)
    self.memory[self.position] = sample
    self.position = (self.position + 1) % self.capacity

  def sample(self, batch_size):
    indices = self.rng.choice(len(self.memory), size=batch_size)
    samples = [self.memory[idx] for idx in indices]
    return map(np.asarray, zip(*samples))

  def __len__(self):
    return len(self.memory)

# %%
class QNet(nn.Module):
  def __init__(self, obs_size, n_actions):
    super(QNet, self).__init__()
    #self.fc1 = nn.Linear(obs_size, n_actions)
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    #  TO DO : Implement network & Forward method
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    self.fc1 = nn.Linear(obs_size, 64)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(64, 64)
    self.fc3 = nn.Linear(64, n_actions)

  def forward(self, state):
    Q = self.fc1(state)
    Q = self.relu(Q)
    Q = self.fc2(Q)
    Q = self.relu(Q)
    Q = self.fc3(Q)
    return Q


class DuelingQNet(nn.Module):
  def __init__(self, obs_size, n_actions):
    super(DuelingQNet, self).__init__()
    #self.fc1 = nn.Linear(obs_size, n_actions)
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    #  TO DO : Implement network & Forward method
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    self.fc1 = nn.Linear(obs_size, 64)
    self.relu = nn.ReLU()
    self.fc2v = nn.Linear(64, 64)
    self.fc3v = nn.Linear(64, 1)

    self.fc2a = nn.Linear(64, 64)
    self.fc3a = nn.Linear(64, n_actions)


  def forward(self, state):
    Q = self.fc1(state)

    #computing V
    V = self.relu(Q)
    V = self.fc2v(V)
    V = self.relu(V)
    V = self.fc3v(V)

    #computing A
    A = self.relu(Q)
    A = self.fc2a(A)
    A = self.relu(A)
    A = self.fc3a(A)

    return A - torch.mean(A) + V

# %%
# Parameters
DQN_TRAINING_TIMESTEPS = 10000  # number of timesteps for training. You might change this!

DQN_PARAMS = dict(
    dueling_dqn=False,         # set to true to use dueling DQN
    double_dqn=False,          # set to true to use double DQN
    gamma=0.99,
    batch_size=256,            # batch size (in number of transitions)
    eval_every=250,            # evaluate every ... steps
    buffer_capacity=30000,     # capacity of the replay buffer
    update_target_every=500,   # update target net every ... steps
    epsilon_start=1.0,         # initial value of epsilon
    epsilon_min=0.05,          # minimum value of epsilon
    decrease_epsilon=5000,     # parameter to decrease epsilon
    learning_rate=0.001,       # learning rate
)
DUELING_DQN_PARAMS = deepcopy(DQN_PARAMS)           # dueling DQN
DOUBLE_DQN_PARAMS = deepcopy(DQN_PARAMS)            # double DQN
DOUBLE_DUELING_DQN_PARAMS = deepcopy(DQN_PARAMS)    # double & dueling DQN

DUELING_DQN_PARAMS.update(dict(dueling_dqn=True))
DOUBLE_DQN_PARAMS.update(dict(double_dqn=True))
DOUBLE_DUELING_DQN_PARAMS.update(dueling_dqn=True, double_dqn=True)

# %%
class DQNAgent(Agent):
  name = 'DQN'
  def __init__(
      self,
      env,
      dueling_dqn: bool,               # Set to true for dueling DQN
      double_dqn: bool,                # Set to true for double DQN
      gamma: float = 0.99,
      batch_size: int = 256,
      eval_every: int = 500,
      buffer_capacity: int = 30000,
      update_target_every: int = 500,
      epsilon_start: float = 1.0,
      epsilon_min: float = 0.05,
      decrease_epsilon: int = 200,
      learning_rate: float = 0.001,
      **kwargs):
    Agent.__init__(self, env, **kwargs)
    env = self.env
    self.dueling_dqn = dueling_dqn
    self.double_dqn = double_dqn
    self.gamma = gamma
    self.batch_size = batch_size
    self.eval_every = eval_every
    self.update_target_every = update_target_every
    self.epsilon_start = epsilon_start
    self.epsilon_min = epsilon_min
    self.decrease_epsilon = decrease_epsilon
    self.total_timesteps = 0
    self.total_episodes = 0
    self.total_updates = 0

    # initialize epsilon
    self.epsilon = epsilon_start

    # initialize replay buffer
    self.replay_buffer = ReplayBuffer(buffer_capacity, self.rng)

    # select network class
    if self.dueling_dqn:
      net_class = DuelingQNet
    else:
      net_class = QNet

    # update name according to params
    if self.dueling_dqn:
      self.name = 'Dueling' + self.name
    if self.double_dqn:
      self.name = 'Double' + self.name

    # create network and target network
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n
    self.q_net = net_class(obs_size, n_actions)
    self.target_net = net_class(obs_size, n_actions)
    self.target_net.load_state_dict(self.q_net.state_dict())
    self.target_net.eval()

    # objective and optimizer
    self.optimizer = optim.Adam(
        params=self.q_net.parameters(), lr=learning_rate)
    self.loss_fn = nn.MSELoss()

  def select_action(self, state, evaluation=False):
    """
    If evaluation=False, get action according to exploration policy.
    Otherwise, get action according to the evaluation policy.
    """
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # TODO: implement action selection strategy
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    action = None
    if self.rng.uniform() < self.epsilon and (not evaluation):
      action = self.env.action_space.sample()# this happens with probability epsilon
    else:
      action = torch.argmax(self.q_net(torch.FloatTensor(state))).item()
    return action # replace by the action you computed

  def fit(self, budget):
    """
    budget : number of training timesteps
    """
    state = self.env.reset()
    done = False
    episode_reward = 0.0
    for tt in range(budget):
      self.total_timesteps += 1
      action = self.select_action(state, evaluation=False)
      next_state, reward, done, _ = self.env.step(action)
      episode_reward += reward
      self.replay_buffer.push((state, next_state, action, reward, done))

      if len(self.replay_buffer) > self.batch_size:
        #
        # Update model
        #
        self.total_updates += 1

        # get batch
        (batch_state, batch_next_state,
         batch_action, batch_reward,
         batch_done) = self.replay_buffer.sample(self.batch_size)
        # convert to torch tensors
        batch_state = torch.FloatTensor(batch_state).to(device)
        batch_next_state = torch.FloatTensor(batch_next_state).to(device)
        batch_action = torch.LongTensor(batch_action).unsqueeze(1).to(device)
        batch_reward = torch.FloatTensor(batch_reward).unsqueeze(1).to(device)
        batch_done = torch.FloatTensor(batch_done).unsqueeze(1).to(device)

        # decrease epsilon
        if self.epsilon > self.epsilon_min:
            self.epsilon -= (self.epsilon_start 
                             - self.epsilon_min) / self.decrease_epsilon

        #
        #  TO DO: compute loss and update networks
        #
        if not self.double_dqn:
          # !!!!!!!!!!!!!!!!!!!!!!!!!!
          # TO DO: compute DQN targets
          # !!!!!!!!!!!!!!!!!!!!!!!!!!

          # values = Q(s_t, a_t), for t in batch
          values = self.q_net(batch_state).gather(1, batch_action.long())

          with torch.no_grad():
            targets = torch.zeros_like(values)
            targets = batch_reward + self.gamma * torch.argmax(self.target_net(batch_next_state), dim=1, keepdim=True) * (1 - batch_done)
      
        else:
          # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
          # TO DO: compute Double DQN targets
          # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
          values = self.q_net(batch_state).gather(1, batch_action.long())
          with torch.no_grad():
            targets = torch.zeros_like(values)
            greedy_actions = torch.argmax(self.q_net(batch_next_state), dim=1, keepdim=True)
            targets = batch_reward + (self.gamma * self.target_net(batch_next_state).gather(1, greedy_actions.long())) * (1 - batch_done)


        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        # TO DO: compute loss and take gradient step
        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        #loss = torch.tensor(0.0)
        self.optimizer.zero_grad()
        loss = self.loss_fn(values, targets)
        loss.backward()
        nn.utils.clip_grad_norm_(self.q_net.parameters(), 1)        
        self.optimizer.step()
        self.writer.add_scalar('loss', loss.item(), self.total_timesteps)

      # evaluate agent
      if self.total_timesteps % self.eval_every == 0:
          mean_rewards = self.eval(n_sim=5)
          self.writer.add_scalar(
              'eval_rewards', mean_rewards, self.total_timesteps)
      
      # update target network
      if self.total_updates % self.update_target_every == 0:
          self.target_net.load_state_dict(self.q_net.state_dict())
          self.target_net.eval()

      # check end of episode
      state = next_state
      if done:
        state = self.env.reset()
        self.total_episodes += 1
        self.writer.add_scalar(
                'episode_rewards', episode_reward, self.total_timesteps)
        self.writer.add_scalar(
                'episode', self.total_episodes, self.total_timesteps)
        episode_reward = 0.0

  def eval(self, n_sim=1, **kwargs):
    rewards = np.zeros(n_sim)
    eval_env = self.eval_env     # evaluation environment
    # Loop over number of simulations
    for sim in range(n_sim):
      state = eval_env.reset()
      done = False
      while not done:
        action = self.select_action(state, evaluation=True)
        next_state, reward, done, _ = eval_env.step(action)
        # update sum of rewards
        rewards[sim] += reward
        state = next_state
    return rewards.mean()

# %%
# # Training one instance of DQN
# dqn_agent = DQNAgent(
#     env=(get_env, dict()),  # we can send (constructor, kwargs) as an env
#     **DQN_PARAMS
# )
# dqn_agent.fit(DQN_TRAINING_TIMESTEPS)

#
# Training several instances using AgentManager
#
manager_kwargs = dict(
    agent_class=DQNAgent,
    train_env=(get_env, dict()),
    eval_env=(get_env, dict()),
    fit_budget=DQN_TRAINING_TIMESTEPS,
    n_fit=4,                   # NOTE: You may increase this parameter (number of agents to train)
    parallelization='thread',
    seed=456,
    default_writer_kwargs=dict(maxlen=None,log_interval=10),
)

# %%
# DQN
dqn_manager = AgentManager(
    init_kwargs=DQN_PARAMS,
    agent_name='DQN',
    **manager_kwargs
)
dqn_manager.fit()
# Out:
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for DQN...
# INFO: Making new env: CartPole-v0
# /usr/local/lib/python3.8/dist-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# [INFO] [DQN[worker: 1]] | max_global_step = 713 | episode_rewards = 20.0 | dw_time_elapsed = 10.012339382999926 | episode = 32 | eval_rewards = 22.2 | loss = 0.027317924425005913 |
# [INFO] [DQN[worker: 0]] | max_global_step = 719 | episode_rewards = 14.0 | dw_time_elapsed = 10.000899175999962 | episode = 36 | eval_rewards = 9.8 | loss = 0.006045419257134199 |
# [INFO] [DQN[worker: 3]] | max_global_step = 717 | episode_rewards = 13.0 | dw_time_elapsed = 10.002672565000012 | episode = 37 | eval_rewards = 11.4 | loss = 9.716339991427958e-05 |
# [INFO] [DQN[worker: 2]] | max_global_step = 722 | episode_rewards = 22.0 | dw_time_elapsed = 10.023598283999945 | episode = 32 | eval_rewards = 18.6 | loss = 2.477995258232113e-05 |
# [INFO] [DQN[worker: 1]] | max_global_step = 1195 | episode_rewards = 19.0 | dw_time_elapsed = 20.02248891599993 | episode = 59 | eval_rewards = 10.2 | loss = 0.0815490111708641 |
# [INFO] [DQN[worker: 0]] | max_global_step = 1189 | episode_rewards = 24.0 | dw_time_elapsed = 20.018836706000002 | episode = 55 | eval_rewards = 9.2 | loss = 0.10589954257011414 |
# [INFO] [DQN[worker: 3]] | max_global_step = 1192 | episode_rewards = 19.0 | dw_time_elapsed = 20.013904528000012 | episode = 59 | eval_rewards = 16.0 | loss = 0.13885627686977386 |
# [INFO] [DQN[worker: 2]] | max_global_step = 1189 | episode_rewards = 10.0 | dw_time_elapsed = 20.024925744999905 | episode = 51 | eval_rewards = 12.6 | loss = 0.10610838979482651 |
# [INFO] [DQN[worker: 1]] | max_global_step = 1615 | episode_rewards = 18.0 | dw_time_elapsed = 30.034012795999956 | episode = 84 | eval_rewards = 15.8 | loss = 0.044698603451251984 |
# [INFO] [DQN[worker: 0]] | max_global_step = 1593 | episode_rewards = 19.0 | dw_time_elapsed = 30.039382085999932 | episode = 74 | eval_rewards = 13.4 | loss = 0.07333987951278687 |
# [INFO] [DQN[worker: 3]] | max_global_step = 1590 | episode_rewards = 43.0 | dw_time_elapsed = 30.026764397999955 | episode = 77 | eval_rewards = 47.0 | loss = 0.07377830147743225 |
# [INFO] [DQN[worker: 2]] | max_global_step = 1598 | episode_rewards = 16.0 | dw_time_elapsed = 30.03396235799994 | episode = 70 | eval_rewards = 44.8 | loss = 0.05843774601817131 |
# [INFO] [DQN[worker: 1]] | max_global_step = 2080 | episode_rewards = 38.0 | dw_time_elapsed = 40.049050130999944 | episode = 97 | eval_rewards = 45.2 | loss = 0.055482976138591766 |
# [INFO] [DQN[worker: 3]] | max_global_step = 2052 | episode_rewards = 20.0 | dw_time_elapsed = 40.031916412999976 | episode = 91 | eval_rewards = 33.2 | loss = 0.05286071449518204 |
# [INFO] [DQN[worker: 2]] | max_global_step = 2052 | episode_rewards = 26.0 | dw_time_elapsed = 40.038021047999905 | episode = 86 | eval_rewards = 63.4 | loss = 0.05694275349378586 |
# [INFO] [DQN[worker: 0]] | max_global_step = 2066 | episode_rewards = 18.0 | dw_time_elapsed = 40.06727003399999 | episode = 98 | eval_rewards = 30.8 | loss = 0.047471288591623306 |
# [INFO] [DQN[worker: 1]] | max_global_step = 2492 | episode_rewards = 31.0 | dw_time_elapsed = 50.05306981199999 | episode = 110 | eval_rewards = 103.0 | loss = 0.06163783743977547 |
# [INFO] [DQN[worker: 3]] | max_global_step = 2492 | episode_rewards = 12.0 | dw_time_elapsed = 50.041154602999995 | episode = 113 | eval_rewards = 31.8 | loss = 0.05844564363360405 |
# [INFO] [DQN[worker: 2]] | max_global_step = 2492 | episode_rewards = 19.0 | dw_time_elapsed = 50.07026251699995 | episode = 104 | eval_rewards = 52.8 | loss = 0.04453268274664879 |
# [INFO] [DQN[worker: 0]] | max_global_step = 2500 | episode_rewards = 28.0 | dw_time_elapsed = 50.52996709399997 | episode = 109 | eval_rewards = 89.0 | loss = 0.0469391793012619 |
# [INFO] [DQN[worker: 1]] | max_global_step = 2917 | episode_rewards = 14.0 | dw_time_elapsed = 60.0638844849999 | episode = 135 | eval_rewards = 22.4 | loss = 0.06987428665161133 |
# [INFO] [DQN[worker: 3]] | max_global_step = 2926 | episode_rewards = 27.0 | dw_time_elapsed = 60.05646376199991 | episode = 134 | eval_rewards = 15.6 | loss = 0.055102940648794174 |
# [INFO] [DQN[worker: 2]] | max_global_step = 2917 | episode_rewards = 12.0 | dw_time_elapsed = 60.07846835599992 | episode = 125 | eval_rewards = 20.0 | loss = 0.04256748780608177 |
# [INFO] [DQN[worker: 0]] | max_global_step = 2893 | episode_rewards = 22.0 | dw_time_elapsed = 60.53391253999996 | episode = 120 | eval_rewards = 135.8 | loss = 0.10484042763710022 |
# [INFO] [DQN[worker: 1]] | max_global_step = 3349 | episode_rewards = 14.0 | dw_time_elapsed = 70.07853389299999 | episode = 166 | eval_rewards = 12.4 | loss = 0.05950314551591873 |
# [INFO] [DQN[worker: 3]] | max_global_step = 3335 | episode_rewards = 32.0 | dw_time_elapsed = 70.068771578 | episode = 149 | eval_rewards = 22.0 | loss = 0.06416065245866776 |
# [INFO] [DQN[worker: 2]] | max_global_step = 3338 | episode_rewards = 22.0 | dw_time_elapsed = 70.10187815899997 | episode = 147 | eval_rewards = 21.2 | loss = 0.05841607600450516 |
# [INFO] [DQN[worker: 0]] | max_global_step = 3311 | episode_rewards = 11.0 | dw_time_elapsed = 70.55608710799993 | episode = 139 | eval_rewards = 24.6 | loss = 0.09133293479681015 |
# [INFO] [DQN[worker: 1]] | max_global_step = 3795 | episode_rewards = 25.0 | dw_time_elapsed = 80.09079479899992 | episode = 193 | eval_rewards = 14.6 | loss = 0.12565559148788452 |
# [INFO] [DQN[worker: 3]] | max_global_step = 3761 | episode_rewards = 78.0 | dw_time_elapsed = 80.08163765699999 | episode = 155 | eval_rewards = 60.2 | loss = 0.32731521129608154 |
# [INFO] [DQN[worker: 2]] | max_global_step = 3771 | episode_rewards = 48.0 | dw_time_elapsed = 80.10735757999998 | episode = 157 | eval_rewards = 35.8 | loss = 0.13940659165382385 |
# [INFO] [DQN[worker: 0]] | max_global_step = 3765 | episode_rewards = 12.0 | dw_time_elapsed = 80.57169059499995 | episode = 173 | eval_rewards = 12.2 | loss = 0.20988616347312927 |
# [INFO] [DQN[worker: 1]] | max_global_step = 4196 | episode_rewards = 35.0 | dw_time_elapsed = 90.11140310600001 | episode = 201 | eval_rewards = 74.6 | loss = 0.0514194630086422 |
# [INFO] [DQN[worker: 3]] | max_global_step = 4169 | episode_rewards = 32.0 | dw_time_elapsed = 90.09540866499992 | episode = 171 | eval_rewards = 30.0 | loss = 0.03569650650024414 |
# [INFO] [DQN[worker: 2]] | max_global_step = 4172 | episode_rewards = 127.0 | dw_time_elapsed = 90.11311920599996 | episode = 162 | eval_rewards = 43.8 | loss = 0.04296688362956047 |
# [INFO] [DQN[worker: 0]] | max_global_step = 4177 | episode_rewards = 27.0 | dw_time_elapsed = 90.58154729499995 | episode = 190 | eval_rewards = 24.4 | loss = 0.05323527753353119 |
# [INFO] [DQN[worker: 1]] | max_global_step = 4610 | episode_rewards = 19.0 | dw_time_elapsed = 100.11720017300001 | episode = 220 | eval_rewards = 27.4 | loss = 0.026859993115067482 |
# [INFO] [DQN[worker: 3]] | max_global_step = 4604 | episode_rewards = 13.0 | dw_time_elapsed = 100.10689232499999 | episode = 198 | eval_rewards = 12.4 | loss = 0.03387007117271423 |
# [INFO] [DQN[worker: 2]] | max_global_step = 4594 | episode_rewards = 22.0 | dw_time_elapsed = 100.12778630799994 | episode = 181 | eval_rewards = 19.2 | loss = 0.06713194400072098 |
# [INFO] [DQN[worker: 0]] | max_global_step = 4566 | episode_rewards = 75.0 | dw_time_elapsed = 100.58883770299997 | episode = 196 | eval_rewards = 148.4 | loss = 0.03662678971886635 |
# [INFO] [DQN[worker: 1]] | max_global_step = 5038 | episode_rewards = 14.0 | dw_time_elapsed = 110.12024609699995 | episode = 252 | eval_rewards = 11.4 | loss = 0.08491183817386627 |
# [INFO] [DQN[worker: 3]] | max_global_step = 5030 | episode_rewards = 20.0 | dw_time_elapsed = 110.11831332499992 | episode = 222 | eval_rewards = 22.8 | loss = 0.047754012048244476 |
# [INFO] [DQN[worker: 2]] | max_global_step = 5020 | episode_rewards = 15.0 | dw_time_elapsed = 110.14791628199998 | episode = 208 | eval_rewards = 13.8 | loss = 0.04985509440302849 |
# [INFO] [DQN[worker: 0]] | max_global_step = 4943 | episode_rewards = 23.0 | dw_time_elapsed = 110.59050624899999 | episode = 203 | eval_rewards = 177.4 | loss = 0.04600504785776138 |
# [INFO] [DQN[worker: 1]] | max_global_step = 5467 | episode_rewards = 24.0 | dw_time_elapsed = 120.1340572009999 | episode = 282 | eval_rewards = 12.0 | loss = 0.04247093200683594 |
# [INFO] [DQN[worker: 3]] | max_global_step = 5462 | episode_rewards = 54.0 | dw_time_elapsed = 120.12106768000001 | episode = 233 | eval_rewards = 21.4 | loss = 0.03593570739030838 |
# [INFO] [DQN[worker: 2]] | max_global_step = 5453 | episode_rewards = 40.0 | dw_time_elapsed = 120.15916211499996 | episode = 230 | eval_rewards = 15.6 | loss = 0.05435972288250923 |
# [INFO] [DQN[worker: 0]] | max_global_step = 5379 | episode_rewards = 13.0 | dw_time_elapsed = 120.601436777 | episode = 227 | eval_rewards = 25.4 | loss = 0.0674285888671875 |
# [INFO] [DQN[worker: 1]] | max_global_step = 5877 | episode_rewards = 47.0 | dw_time_elapsed = 130.15180953999993 | episode = 299 | eval_rewards = 20.0 | loss = 0.05824018269777298 |
# [INFO] [DQN[worker: 3]] | max_global_step = 5814 | episode_rewards = 87.0 | dw_time_elapsed = 130.14325861700001 | episode = 237 | eval_rewards = 102.2 | loss = 0.07453632354736328 |
# [INFO] [DQN[worker: 2]] | max_global_step = 5856 | episode_rewards = 103.0 | dw_time_elapsed = 130.159261066 | episode = 240 | eval_rewards = 31.4 | loss = 0.07545150816440582 |
# [INFO] [DQN[worker: 0]] | max_global_step = 5783 | episode_rewards = 12.0 | dw_time_elapsed = 130.61690848699993 | episode = 262 | eval_rewards = 11.2 | loss = 0.08761297911405563 |
# [INFO] [DQN[worker: 3]] | max_global_step = 6211 | episode_rewards = 24.0 | dw_time_elapsed = 140.150809847 | episode = 252 | eval_rewards = 29.6 | loss = 0.04344182461500168 |
# [INFO] [DQN[worker: 2]] | max_global_step = 6245 | episode_rewards = 55.0 | dw_time_elapsed = 140.16735854499996 | episode = 246 | eval_rewards = 50.4 | loss = 0.05380726233124733 |
# [INFO] [DQN[worker: 1]] | max_global_step = 6250 | episode_rewards = 80.0 | dw_time_elapsed = 140.5197482499999 | episode = 305 | eval_rewards = 74.8 | loss = 0.028007708489894867 |
# [INFO] [DQN[worker: 0]] | max_global_step = 6183 | episode_rewards = 29.0 | dw_time_elapsed = 140.62540767299993 | episode = 278 | eval_rewards = 26.0 | loss = 0.047532692551612854 |
# [INFO] [DQN[worker: 3]] | max_global_step = 6621 | episode_rewards = 18.0 | dw_time_elapsed = 150.15785396899992 | episode = 279 | eval_rewards = 14.6 | loss = 0.057206351310014725 |
# [INFO] [DQN[worker: 2]] | max_global_step = 6640 | episode_rewards = 21.0 | dw_time_elapsed = 150.202482477 | episode = 264 | eval_rewards = 21.2 | loss = 0.04359832778573036 |
# [INFO] [DQN[worker: 1]] | max_global_step = 6678 | episode_rewards = 25.0 | dw_time_elapsed = 150.52663230199994 | episode = 320 | eval_rewards = 21.6 | loss = 0.024382367730140686 |
# [INFO] [DQN[worker: 0]] | max_global_step = 6555 | episode_rewards = 100.0 | dw_time_elapsed = 150.64036716299995 | episode = 285 | eval_rewards = 180.4 | loss = 0.03346959501504898 |
# [INFO] [DQN[worker: 3]] | max_global_step = 7023 | episode_rewards = 17.0 | dw_time_elapsed = 160.15822265499992 | episode = 302 | eval_rewards = 18.8 | loss = 0.05404732748866081 |
# [INFO] [DQN[worker: 2]] | max_global_step = 7045 | episode_rewards = 16.0 | dw_time_elapsed = 160.22164905399995 | episode = 290 | eval_rewards = 13.8 | loss = 0.06868278235197067 |
# [INFO] [DQN[worker: 1]] | max_global_step = 7089 | episode_rewards = 20.0 | dw_time_elapsed = 160.54513833199996 | episode = 347 | eval_rewards = 10.6 | loss = 0.07563720643520355 |
# [INFO] [DQN[worker: 0]] | max_global_step = 6919 | episode_rewards = 25.0 | dw_time_elapsed = 160.64574762799998 | episode = 292 | eval_rewards = 162.6 | loss = 0.05620843172073364 |
# [INFO] [DQN[worker: 3]] | max_global_step = 7444 | episode_rewards = 55.0 | dw_time_elapsed = 170.171177887 | episode = 318 | eval_rewards = 12.2 | loss = 0.05637948215007782 |
# [INFO] [DQN[worker: 2]] | max_global_step = 7462 | episode_rewards = 29.0 | dw_time_elapsed = 170.248394502 | episode = 314 | eval_rewards = 14.8 | loss = 0.0630064383149147 |
# [INFO] [DQN[worker: 1]] | max_global_step = 7499 | episode_rewards = 29.0 | dw_time_elapsed = 170.54743407399997 | episode = 372 | eval_rewards = 15.0 | loss = 0.08473972231149673 |
# [INFO] [DQN[worker: 0]] | max_global_step = 7330 | episode_rewards = 14.0 | dw_time_elapsed = 170.672647181 | episode = 311 | eval_rewards = 29.6 | loss = 0.09483277797698975 |
# [INFO] [DQN[worker: 3]] | max_global_step = 7761 | episode_rewards = 89.0 | dw_time_elapsed = 180.19696331499995 | episode = 321 | eval_rewards = 154.2 | loss = 0.39144259691238403 |
# [INFO] [DQN[worker: 2]] | max_global_step = 7837 | episode_rewards = 62.0 | dw_time_elapsed = 180.2673930829999 | episode = 323 | eval_rewards = 42.2 | loss = 0.08755943924188614 |
# [INFO] [DQN[worker: 1]] | max_global_step = 7882 | episode_rewards = 58.0 | dw_time_elapsed = 180.55977363099998 | episode = 383 | eval_rewards = 24.6 | loss = 0.08321072161197662 |
# [INFO] [DQN[worker: 0]] | max_global_step = 7732 | episode_rewards = 12.0 | dw_time_elapsed = 180.69520746799992 | episode = 341 | eval_rewards = 13.8 | loss = 0.04053622484207153 |
# [INFO] [DQN[worker: 3]] | max_global_step = 8176 | episode_rewards = 38.0 | dw_time_elapsed = 190.21590847599998 | episode = 333 | eval_rewards = 32.2 | loss = 0.0383816659450531 |
# [INFO] [DQN[worker: 2]] | max_global_step = 8229 | episode_rewards = 84.0 | dw_time_elapsed = 190.28377390599996 | episode = 327 | eval_rewards = 103.8 | loss = 0.03790464252233505 |
# [INFO] [DQN[worker: 1]] | max_global_step = 8261 | episode_rewards = 58.0 | dw_time_elapsed = 190.57526911599996 | episode = 388 | eval_rewards = 70.2 | loss = 0.2981966733932495 |
# [INFO] [DQN[worker: 0]] | max_global_step = 8148 | episode_rewards = 34.0 | dw_time_elapsed = 190.70900469799994 | episode = 358 | eval_rewards = 24.8 | loss = 0.046944569796323776 |
# [INFO] [DQN[worker: 3]] | max_global_step = 8609 | episode_rewards = 15.0 | dw_time_elapsed = 200.22835828999996 | episode = 357 | eval_rewards = 17.6 | loss = 0.048580631613731384 |
# [INFO] [DQN[worker: 2]] | max_global_step = 8626 | episode_rewards = 19.0 | dw_time_elapsed = 200.3013544449999 | episode = 344 | eval_rewards = 24.6 | loss = 0.04148995876312256 |
# [INFO] [DQN[worker: 1]] | max_global_step = 8700 | episode_rewards = 27.0 | dw_time_elapsed = 200.6123707449999 | episode = 405 | eval_rewards = 25.4 | loss = 0.046779680997133255 |
# [INFO] [DQN[worker: 0]] | max_global_step = 8534 | episode_rewards = 120.0 | dw_time_elapsed = 200.71782469200002 | episode = 364 | eval_rewards = 176.2 | loss = 0.050037726759910583 |
# [INFO] [DQN[worker: 3]] | max_global_step = 9020 | episode_rewards = 17.0 | dw_time_elapsed = 210.25077907399998 | episode = 381 | eval_rewards = 19.4 | loss = 0.048471637070178986 |
# [INFO] [DQN[worker: 2]] | max_global_step = 9042 | episode_rewards = 9.0 | dw_time_elapsed = 210.30957438999997 | episode = 373 | eval_rewards = 11.8 | loss = 0.0799136757850647 |
# [INFO] [DQN[worker: 1]] | max_global_step = 9120 | episode_rewards = 26.0 | dw_time_elapsed = 210.63082133599994 | episode = 422 | eval_rewards = 22.6 | loss = 0.051675569266080856 |
# [INFO] [DQN[worker: 0]] | max_global_step = 8910 | episode_rewards = 35.0 | dw_time_elapsed = 210.721504245 | episode = 370 | eval_rewards = 182.0 | loss = 0.06363993138074875 |
# [INFO] [DQN[worker: 3]] | max_global_step = 9433 | episode_rewards = 76.0 | dw_time_elapsed = 220.279759614 | episode = 395 | eval_rewards = 20.8 | loss = 0.05625171959400177 |
# [INFO] [DQN[worker: 2]] | max_global_step = 9466 | episode_rewards = 32.0 | dw_time_elapsed = 220.31494093699996 | episode = 399 | eval_rewards = 12.4 | loss = 0.05841032415628433 |
# [INFO] [DQN[worker: 1]] | max_global_step = 9500 | episode_rewards = 47.0 | dw_time_elapsed = 220.69439901299995 | episode = 431 | eval_rewards = 103.4 | loss = 0.044299207627773285 |
# [INFO] [DQN[worker: 0]] | max_global_step = 9311 | episode_rewards = 14.0 | dw_time_elapsed = 220.74434822799992 | episode = 387 | eval_rewards = 29.6 | loss = 0.10592798888683319 |
# [INFO] [DQN[worker: 3]] | max_global_step = 9810 | episode_rewards = 53.0 | dw_time_elapsed = 230.30935793499998 | episode = 402 | eval_rewards = 62.0 | loss = 0.058887213468551636 |
# [INFO] [DQN[worker: 2]] | max_global_step = 9871 | episode_rewards = 112.0 | dw_time_elapsed = 230.3319104599999 | episode = 409 | eval_rewards = 34.4 | loss = 0.07380829006433487 |
# [INFO] [DQN[worker: 1]] | max_global_step = 9898 | episode_rewards = 123.0 | dw_time_elapsed = 230.70633106899993 | episode = 436 | eval_rewards = 83.8 | loss = 0.06644962728023529 |
# [INFO] [DQN[worker: 0]] | max_global_step = 9734 | episode_rewards = 19.0 | dw_time_elapsed = 230.75717726999994 | episode = 422 | eval_rewards = 14.0 | loss = 0.04987349733710289 |
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
# Double DQN
double_dqn_manager = AgentManager(
    init_kwargs=DOUBLE_DQN_PARAMS,
    agent_name='DoubleDQN',
    **manager_kwargs
)
double_dqn_manager.fit()
# Out:
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for DoubleDQN...
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 695 | episode_rewards = 36.0 | dw_time_elapsed = 10.006058442999915 | episode = 30 | eval_rewards = 9.2 | loss = 0.00017872326134238392 |
# [INFO] [DoubleDQN[worker: 1]] | max_global_step = 697 | episode_rewards = 17.0 | dw_time_elapsed = 10.008137678000026 | episode = 28 | eval_rewards = 19.4 | loss = 0.009334370493888855 |
# [INFO] [DoubleDQN[worker: 2]] | max_global_step = 693 | episode_rewards = 12.0 | dw_time_elapsed = 10.009471371000018 | episode = 34 | eval_rewards = 11.2 | loss = 0.0018807932501658797 |
# [INFO] [DoubleDQN[worker: 3]] | max_global_step = 704 | episode_rewards = 42.0 | dw_time_elapsed = 10.012051800999984 | episode = 33 | eval_rewards = 9.0 | loss = 0.0017083999700844288 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 1120 | episode_rewards = 18.0 | dw_time_elapsed = 20.015259474999993 | episode = 48 | eval_rewards = 9.2 | loss = 0.028489749878644943 |
# [INFO] [DoubleDQN[worker: 2]] | max_global_step = 1123 | episode_rewards = 12.0 | dw_time_elapsed = 20.014598831999933 | episode = 53 | eval_rewards = 9.4 | loss = 0.015984853729605675 |
# [INFO] [DoubleDQN[worker: 1]] | max_global_step = 1096 | episode_rewards = 51.0 | dw_time_elapsed = 20.02781540600006 | episode = 45 | eval_rewards = 80.0 | loss = 0.022910283878445625 |
# [INFO] [DoubleDQN[worker: 3]] | max_global_step = 1139 | episode_rewards = 20.0 | dw_time_elapsed = 20.01297427299994 | episode = 47 | eval_rewards = 21.6 | loss = 0.011235053651034832 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 1545 | episode_rewards = 31.0 | dw_time_elapsed = 30.027515066999968 | episode = 66 | eval_rewards = 9.4 | loss = 0.06071211397647858 |
# [INFO] [DoubleDQN[worker: 1]] | max_global_step =
|
# [INFO] [DoubleDQN[worker: 3]] | max_global_step = 9253 | episode_rewards = 109.0 | dw_time_elapsed = 243.09026493500005 | episode = 144 | eval_rewards = 108.6 | loss = 0.4302912950515747 |
# [INFO] [DoubleDQN[worker: 2]] | max_global_step = 8999 | episode_rewards = 200.0 | dw_time_elapsed = 243.292700598 | episode = 148 | eval_rewards = 200.0 | loss = 0.5326479077339172 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 9397 | episode_rewards = 200.0 | dw_time_elapsed = 250.4922079239999 | episode = 143 | eval_rewards = 191.6 | loss = 0.36822110414505005 |
# [INFO] [DoubleDQN[worker: 1]] | max_global_step = 9432 | episode_rewards = 178.0 | dw_time_elapsed = 252.1958171540001 | episode = 147 | eval_rewards = 118.2 | loss = 1.422402262687683 |
# [INFO] [DoubleDQN[worker: 3]] | max_global_step = 9607 | episode_rewards = 109.0 | dw_time_elapsed = 253.09517765200007 | episode = 147 | eval_rewards = 130.8 | loss = 0.28739017248153687 |
# [INFO] [DoubleDQN[worker: 2]] | max_global_step = 9275 | episode_rewards = 200.0 | dw_time_elapsed = 253.30364938999992 | episode = 149 | eval_rewards = 200.0 | loss = 0.23292428255081177 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 9730 | episode_rewards = 200.0 | dw_time_elapsed = 260.5001704759999 | episode = 144 | eval_rewards = 200.0 | loss = 0.08544065058231354 |
# [INFO] [DoubleDQN[worker: 1]] | max_global_step = 9755 | episode_rewards = 168.0 | dw_time_elapsed = 262.21962948199996 | episode = 148 | eval_rewards = 139.0 | loss = 0.4913458526134491 |
# [INFO] [DoubleDQN[worker: 3]] | max_global_step = 9970 | episode_rewards = 118.0 | dw_time_elapsed = 263.099481063 | episode = 150 | eval_rewards = 106.4 | loss = 0.39333978295326233 |
# [INFO] [DoubleDQN[worker: 2]] | max_global_step = 9620 | episode_rewards = 200.0 | dw_time_elapsed = 263.3072182159999 | episode = 151 | eval_rewards = 200.0 | loss = 0.226680189371109 |
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
# Dueling DQN
dueling_dqn_manager = AgentManager(
    init_kwargs=DUELING_DQN_PARAMS,
    agent_name='DuelingDQN',
    **manager_kwargs
)
dueling_dqn_manager.fit()
# Out:
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for DuelingDQN...
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 606 | episode_rewards = 42.0 | dw_time_elapsed = 10.01081142000021 | episode = 28 | eval_rewards = 32.0 | loss = 0.02416655793786049 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 610 | episode_rewards = 20.0 | dw_time_elapsed = 10.009870842000055 | episode = 28 | eval_rewards = 13.8 | loss = 0.02326424978673458 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 612 | episode_rewards = 26.0 | dw_time_elapsed = 10.001469874999884 | episode = 31 | eval_rewards = 13.2 | loss = 0.03808039426803589 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 537 | episode_rewards = 28.0 | dw_time_elapsed = 10.020239534999973 | episode = 20 | eval_rewards = 200.0 | loss = 0.025411859154701233 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 976 | episode_rewards = 15.0 | dw_time_elapsed = 20.02137040300022 | episode = 44 | eval_rewards = 21.8 | loss = 0.05394085496664047 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 987 | episode_rewards = 22.0 | dw_time_elapsed = 20.029830418000074 | episode = 40 | eval_rewards = 14.6 | loss = 0.08564337342977524 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 990 | episode_rewards = 43.0 | dw_time_elapsed = 20.033345131000033 | episode = 46 | eval_rewards = 21.0 | loss = 0.0679633691906929 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 901 | episode_rewards = 24.0 | dw_time_elapsed = 20.05498106999994 | episode = 37 | eval_rewards = 35.2 | loss = 0.04546754062175751 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 1260 | episode_rewards = 23.0 | dw_time_elapsed = 30.03836850200014 | episode = 52 | eval_rewards = 65.0 | loss = 0.315787672996521 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 1331 | episode_rewards = 35.0 | dw_time_elapsed = 30.04814947 | episode = 54 | eval_rewards = 13.8 | loss = 0.07226371020078659 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 1299 | episode_rewards = 27.0 | dw_time_elapsed = 30.048066127999846 | episode = 52 | eval_rewards = 49.4 | loss = 0.09961792826652527 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 1250 | episode_rewards = 21.0 | dw_time_elapsed = 30.069234687000062 | episode = 57 | eval_rewards = 13.6 | loss = 0.0321393758058548 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 1597 | episode_rewards = 14.0 | dw_time_elapsed = 40.04908536400012 | episode = 65 | eval_rewards = 27.8 | loss = 0.049583643674850464 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 1651 | episode_rewards = 34.0 | dw_time_elapsed = 40.051440404999994 | episode = 64 | eval_rewards = 73.8 | loss = 0.05421438068151474 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 1639 | episode_rewards = 43.0 | dw_time_elapsed = 40.06254117000003 | episode = 65 | eval_rewards = 29.6 | loss = 0.07957662642002106 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 1589 | episode_rewards = 57.0 | dw_time_elapsed = 40.08196292799994 | episode = 74 | eval_rewards = 26.2 | loss = 0.06430862843990326 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 1940 | episode_rewards = 22.0 | dw_time_elapsed = 50.05449569100006 | episode = 81 | eval_rewards = 30.8 | loss = 0.06045812368392944 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 1995 | episode_rewards = 23.0 | dw_time_elapsed = 50.05952158800005 | episode = 78 | eval_rewards = 36.2 | loss = 0.06216132640838623 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 1926 | episode_rewards = 23.0 | dw_time_elapsed = 50.10124885100004 | episode = 86 | eval_rewards = 29.2 | loss = 0.06639500707387924 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 1986 | episode_rewards = 13.0 | dw_time_elapsed = 50.09889321199989 | episode = 85 | eval_rewards = 31.8 | loss = 0.06958955526351929 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 2287 | episode_rewards = 12.0 | dw_time_elapsed = 60.05990436800016 | episode = 100 | eval_rewards = 14.8 | loss = 0.09498587250709534 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 2339 | episode_rewards = 14.0 | dw_time_elapsed = 60.062568832000125 | episode = 99 | eval_rewards = 18.2 | loss = 0.06119626387953758 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 2232 | episode_rewards = 12.0 | dw_time_elapsed = 60.12375994800004 | episode = 92 | eval_rewards = 122.4 | loss = 0.05571332201361656 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 2329 | episode_rewards = 12.0 | dw_time_elapsed = 60.112697669 | episode = 103 | eval_rewards = 15.0 | loss = 0.06503909081220627 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 2634 | episode_rewards = 35.0 | dw_time_elapsed = 70.07924065400016 | episode = 113 | eval_rewards = 33.6 | loss = 0.05282516032457352 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 2691 | episode_rewards = 12.0 | dw_time_elapsed = 70.07621707200019 | episode = 125 | eval_rewards = 10.0 | loss = 0.051561590284109116 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 2676 | episode_rewards = 14.0 | dw_time_elapsed = 70.12950279300003 | episode = 123 | eval_rewards = 15.6 | loss = 0.03917917609214783 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 2558 | episode_rewards = 41.0 | dw_time_elapsed = 70.15842982499998 | episode = 107 | eval_rewards = 26.0 | loss = 0.0574570894241333 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 3049 | episode_rewards = 21.0 | dw_time_elapsed = 80.09065610300013 | episode = 145 | eval_rewards = 18.0 | loss = 0.0500798225402832 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 3016 | episode_rewards = 12.0 | dw_time_elapsed = 80.13297455099996 | episode = 137 | eval_rewards = 47.4 | loss = 0.05420869588851929 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 2919 | episode_rewards = 10.0 | dw_time_elapsed = 80.16246454499992 | episode = 126 | eval_rewards = 25.0 | loss = 0.06455506384372711 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step =
|
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 9505 | episode_rewards = 198.0 | dw_time_elapsed = 292.48397425200005 | episode = 318 | eval_rewards = 99.2 | loss = 0.05751683562994003 |
# [INFO] [DuelingDQN[worker: 3]] | max_global_step = 9996 | episode_rewards = 26.0 | dw_time_elapsed = 300.51860487199997 | episode = 405 | eval_rewards = 58.0 | loss = 0.05920121446251869 |
# [INFO] [DuelingDQN[worker: 1]] | max_global_step = 9335 | episode_rewards = 114.0 | dw_time_elapsed = 300.5959022499999 | episode = 284 | eval_rewards = 122.8 | loss = 0.09672866016626358 |
# [INFO] [DuelingDQN[worker: 2]] | max_global_step = 9750 | episode_rewards = 200.0 | dw_time_elapsed = 302.143676765 | episode = 386 | eval_rewards = 200.0 | loss = 0.042645618319511414 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 9796 | episode_rewards = 131.0 | dw_time_elapsed = 302.49112740300006 | episode = 321 | eval_rewards = 89.2 | loss = 0.10100175440311432 |
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
# Double+Dueling DQN
double_dueling_dqn_manager = AgentManager(
    init_kwargs=DOUBLE_DUELING_DQN_PARAMS,
    agent_name='DoubleDuelingDQN',
    **manager_kwargs
)
double_dueling_dqn_manager.fit()
# Out:
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for DoubleDuelingDQN...
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 565 | episode_rewards = 47.0 | dw_time_elapsed = 10.025332606999882 | episode = 29 | eval_rewards = 9.6 | loss = 0.004209753125905991 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 556 | episode_rewards = 23.0 | dw_time_elapsed = 10.020744658000012 | episode = 24 | eval_rewards = 58.0 | loss = 0.0008006809512153268 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 572 | episode_rewards = 68.0 | dw_time_elapsed = 10.012255862999837 | episode = 25 | eval_rewards = 9.0 | loss = 0.005435059312731028 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 563 | episode_rewards = 16.0 | dw_time_elapsed = 10.02009586500003 | episode = 29 | eval_rewards = 37.0 | loss = 0.0020213089883327484 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 905 | episode_rewards = 58.0 | dw_time_elapsed = 20.034122843999967 | episode = 43 | eval_rewards = 9.2 | loss = 0.042272500693798065 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 908 | episode_rewards = 16.0 | dw_time_elapsed = 20.01247420599998 | episode = 39 | eval_rewards = 9.4 | loss = 0.034208960831165314 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 889 | episode_rewards = 27.0 | dw_time_elapsed = 20.05300120800007 | episode = 38 | eval_rewards = 40.4 | loss = 0.028112314641475677 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 903 | episode_rewards = 13.0 | dw_time_elapsed = 20.05598801300016 | episode = 48 | eval_rewards = 10.8 | loss = 0.017807940021157265 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 1231 | episode_rewards = 9.0 | dw_time_elapsed = 30.052363972999956 | episode = 58 | eval_rewards = 9.2 | loss = 0.02006525732576847 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 1232 | episode_rewards = 38.0 | dw_time_elapsed = 30.037825554999927 | episode = 55 | eval_rewards = 9.6 | loss = 0.01985587552189827 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 1207 | episode_rewards = 19.0 | dw_time_elapsed = 30.066660914000067 | episode = 49 | eval_rewards = 46.6 | loss = 0.021323610097169876 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 1236 | episode_rewards = 38.0 | dw_time_elapsed = 30.064945652999995 | episode = 60 | eval_rewards = 9.4 | loss = 0.015192235819995403 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 1544 | episode_rewards = 19.0 | dw_time_elapsed = 40.05821210099998 | episode = 75 | eval_rewards = 18.6 | loss = 0.025648217648267746 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 1559 | episode_rewards = 61.0 | dw_time_elapsed = 40.06188246399984 | episode = 64 | eval_rewards = 10.2 | loss = 0.03805479779839516 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step =
|
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 8703 | episode_rewards = 127.0 | dw_time_elapsed = 310.5860919460001 | episode = 167 | eval_rewards = 122.0 | loss = 1.2464109659194946 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 8547 | episode_rewards = 200.0 | dw_time_elapsed = 312.2768855940001 | episode = 133 | eval_rewards = 198.0 | loss = 0.0863993763923645 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 8846 | episode_rewards = 129.0 | dw_time_elapsed = 312.328663046 | episode = 173 | eval_rewards = 118.4 | loss = 0.5133083462715149 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 8977 | episode_rewards = 200.0 | dw_time_elapsed = 320.60652249500004 | episode = 168 | eval_rewards = 114.8 | loss = 0.16857174038887024 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 8750 | episode_rewards = 112.0 | dw_time_elapsed = 321.2920690479998 | episode = 157 | eval_rewards = 116.0 | loss = 0.5853947401046753 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 8785 | episode_rewards = 200.0 | dw_time_elapsed = 322.29806005800015 | episode = 134 | eval_rewards = 200.0 | loss = 0.4062268137931824 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 9116 | episode_rewards = 120.0 | dw_time_elapsed = 322.3318075569998 | episode = 175 | eval_rewards = 115.6 | loss = 0.22927437722682953 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 9213 | episode_rewards = 112.0 | dw_time_elapsed = 330.6320017500002 | episode = 170 | eval_rewards = 196.0 | loss = 0.32170793414115906 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 9004 | episode_rewards = 109.0 | dw_time_elapsed = 331.2996820889998 | episode = 159 | eval_rewards = 118.8 | loss = 0.13594384491443634 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 9019 | episode_rewards = 200.0 | dw_time_elapsed = 332.3148531700001 | episode = 135 | eval_rewards = 199.6 | loss = 0.1307574063539505 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 9382 | episode_rewards = 110.0 | dw_time_elapsed = 332.34594333899986 | episode = 177 | eval_rewards = 108.0 | loss = 0.24016858637332916 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 9448 | episode_rewards = 143.0 | dw_time_elapsed = 340.67468078900015 | episode = 171 | eval_rewards = 153.8 | loss = 1.1922539472579956 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 9260 | episode_rewards = 107.0 | dw_time_elapsed = 341.3017724859999 | episode = 161 | eval_rewards = 112.4 | loss = 1.6346006393432617 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 9250 | episode_rewards = 200.0 | dw_time_elapsed = 342.36778870700005 | episode = 136 | eval_rewards = 200.0 | loss = 2.2641868591308594 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 9647 | episode_rewards = 118.0 | dw_time_elapsed = 342.38755335899987 | episode = 180 | eval_rewards = 110.0 | loss = 0.2611061930656433 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 9712 | episode_rewards = 146.0 | dw_time_elapsed = 350.7148379680002 | episode = 173 | eval_rewards = 146.0 | loss = 1.0714764595031738 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 9531 | episode_rewards = 115.0 | dw_time_elapsed = 351.3306584909999 | episode = 163 | eval_rewards = 109.2 | loss = 0.5014174580574036 |
# [INFO] [DoubleDuelingDQN[worker: 2]] | max_global_step = 9923 | episode_rewards = 116.0 | dw_time_elapsed = 352.41147941199984 | episode = 182 | eval_rewards = 120.2 | loss = 1.3039313554763794 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 9500 | episode_rewards = 200.0 | dw_time_elapsed = 352.515113421 | episode = 137 | eval_rewards = 200.0 | loss = 0.21114015579223633 |
# [INFO] [DoubleDuelingDQN[worker: 3]] | max_global_step = 9997 | episode_rewards = 178.0 | dw_time_elapsed = 360.7384299280002 | episode = 175 | eval_rewards = 199.8 | loss = 0.2009323239326477 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 9843 | episode_rewards = 112.0 | dw_time_elapsed = 361.3429187879999 | episode = 165 | eval_rewards = 122.0 | loss = 0.46795520186424255 |
# [INFO] [DoubleDuelingDQN[worker: 1]] | max_global_step = 9776 | episode_rewards = 200.0 | dw_time_elapsed = 362.52126850900004 | episode = 139 | eval_rewards = 200.0 | loss = 1.9462021589279175 |
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
all_dqn_managers = []
all_dqn_managers.append(dqn_manager)
all_dqn_managers.append(double_dqn_manager)
all_dqn_managers.append(dueling_dqn_manager)
all_dqn_managers.append(double_dueling_dqn_manager)

# We can plot the data that was 
# stored by the agent with self.writer.add_scalar(tag, value, global_step):
_ = plot_writer_data(all_dqn_managers, tag='loss', title='Q Loss')
_ = plot_writer_data(all_dqn_managers, tag='eval_rewards', title='Rewards (Evaluation)')
_ = plot_writer_data(all_dqn_managers, tag='eval_rewards', title='Cumulative Rewards (Evaluation)', preprocess_func=np.cumsum)

# rewards in each episode
# Warning: not all runs will have the same number of episodes. Can you see why?
_ = plot_writer_data(all_dqn_managers, tag='episode_rewards', xtag='episode', title='Episode Rewards')
_ = plot_writer_data(all_dqn_managers, tag='episode_rewards', xtag='episode', title='Cumulative Rewards', preprocess_func=np.cumsum)

# %% [markdown]
# # Part 2: REINFORCE

# %% [markdown]
# ## Question 2.1 (written)
#
# In class we have seen the derivation of the policy gradient theorem in the "Monte-Carlo style". Recall that the policy gradient is given by
# $$
#     \nabla_\theta J(\pi_\theta) = \mathbb{E}_{\tau \sim \mathbb{P}(\cdot|\pi_\theta)}\left[ \nabla_\theta \log \mathbb{P}(\tau|\pi_\theta)
#     R(\tau)
#     \right]
# $$
# where $R(\tau) = \sum_{t=1}^{|\tau|} r_t$. By construction the policy gradient is on-policy, we need to estimate the gradient using the samples collected through the current policy $\pi_\theta$.
#
# 1. *Derive an off-policy variant* by assuming to collect samples from a behavioral policy $\mu(s,a)$. The target policy, i.e., the policy for which we want to compute the gradient is $\pi_{\theta}$. Write explicitly the gradient log probability in your derivation.
#
# 2. What are the properties that $\mu$ needs to satisfy to obtain a meaningful gradient estimate?

# %% [markdown]
# 1. To collect samples w.r.t. $\mu$ we have to make it appear in the expectation :
# $$\nabla_{\theta}J(\pi_\theta) = \mathbb{E}_{\tau \sim \mathbb{P}(\cdot|\pi_\theta)}[\nabla_\theta \log \mathbb{P}(\tau|\pi_\theta)R(\tau)]$$
# $$\nabla_{\theta}J(\pi_\theta) = \mathbb{E}_{\tau \sim \mathbb{P}(\cdot|\mu)}[\nabla_\theta \log \mathbb{P}(\tau|\pi_\theta)R(\tau)\frac{\mathbb{P}(\tau|\pi_\theta)}{\mathbb{P}(\tau|\mu)}]$$
# Furthermore we can see that the ratio of the probabilities simplifies. If we write $\tau$ as a trajectory $(s_t, a_t, r_t)_{1 \leq t \leq |\tau|}$:
# $$\frac{\mathbb{P}(\tau|\pi_\theta)}{\mathbb{P}(\tau|\mu)} = \frac{\mathbb{P}(s_1)}{\mathbb{P}(s_1)}\prod_{t=1}^{|\tau|} \frac{\mathbb{P}(s_{t+1}|s_t, a_t)\pi_\theta(s_t, a_t)}{\mathbb{P}(s_{t+1}|s_t, a_t)\mu(s_t, a_t)}$$
# $$\frac{\mathbb{P}(\tau|\pi_\theta)}{\mathbb{P}(\tau|\mu)} = \prod_{t=1}^{|\tau|} \frac{\pi_\theta(s_t, a_t)}{\mu_(s_t, a_t)}$$
# Hence we have :
# $$\nabla_{\theta}J(\pi_\theta) = \mathbb{E}_{\tau \sim \mathbb{P}(\cdot|\mu)}[\sum_{t=1}^{|\tau|}∇_\theta \log \pi_\theta(s_t, a_t)\prod_{t=1}^{|\tau|} \frac{\pi_\theta(s_t, a_t)}{\mu_(s_t, a_t)}\sum_{t=1}^{|\tau|}R(\tau)]$$

# %% [markdown]
# ## Question 2.2 (implementation)
# Starting from the provided code, implement on-policy policy gradient
# $$
#     \nabla_\theta J(\pi_\theta) = \mathbb{E}_{\tau \sim \mathbb{P}(\cdot|\pi_\theta)}\left[ \nabla_\theta \log \mathbb{P}(\tau|\pi_\theta)
#     R(\tau)
#     \right]
# $$
#
# Use the most efficient version of the gradient estimator without baseline (i.e., GPOMDP).

# %%
class PolicyNet(nn.Module):
  def __init__(self, obs_size, n_actions):
    super(PolicyNet, self).__init__()
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    #  TO DO : Implement network & Forward method
    #  You can use the same architecture as DQN
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    self.fc1 = nn.Linear(obs_size, 64)
    self.fc2 = nn.Linear(64, 64)
    self.fc3 = nn.Linear(64, n_actions)
    self.relu = nn.ReLU()
    self.softmax = nn.Softmax(dim=-1)

  def forward(self, state):
    action_logits = self.fc1(state)
    action_logits = self.relu(action_logits)
    action_logits = self.fc2(action_logits)
    action_logits = self.relu(action_logits)
    action_logits = self.fc3(action_logits)

    # compute softmax of the output of the net, to get probabilities over actions
    action_probs = self.softmax(action_logits)
    dist = Categorical(action_probs)
    return action_logits, dist

# %%
# Parameters
REINFORCE_TRAINING_TIMESTEPS = 5*DQN_TRAINING_TIMESTEPS  # number of timesteps for training. You might change this!

REINFORCE_PARAMS = dict(
    gamma=0.99,
    batch_size=200,            # batch size
    eval_every=250,            # evaluate every ... steps
    learning_rate=0.001,       # learning rate
)

# %%
class REINFORCEAgent(Agent):
  name = 'REINFORCE'
  def __init__(
      self,
      env,
      gamma: float = 0.99,
      batch_size: int = 200,
      eval_every: int = 250,
      learning_rate: float = 0.1,
      **kwargs):
    Agent.__init__(self, env, **kwargs)
    env = self.env
    self.gamma = gamma
    self.batch_size = batch_size
    self.eval_every = eval_every
    self.total_timesteps = 0
    self.total_episodes = 0
    self.total_updates = 0
  
    # create network
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n
    self.policy_net = PolicyNet(obs_size, n_actions)

    # optimizer
    self.optimizer = optim.Adam(
        params=self.policy_net.parameters(), lr=learning_rate)

  def select_action(self, state, evaluation=False):
    """
    If evaluation=False, get action according to exploration policy.
    Otherwise, get action according to the evaluation policy.
    """
    tensor_state = torch.FloatTensor(state).to(device)
    with torch.no_grad():
      _, dist = self.policy_net(tensor_state)
      action = dist.sample().item()
    return action

  def fit(self, budget):
    """
    budget : number of training timesteps
    """
    state = self.env.reset()
    done = False
    episode_reward = 0.0

    trajectory_states = []
    trajectory_actions = []
    trajectory_rewards = []
    trajectory_dones = []

    for tt in range(budget):
      self.total_timesteps += 1
      action = self.select_action(state, evaluation=False)
      next_state, reward, done, _ = self.env.step(action)
      episode_reward += reward

      trajectory_states.append(state)
      trajectory_actions.append(action)
      trajectory_rewards.append(reward)
      trajectory_dones.append(done)

      if ((tt + 1) % self.batch_size) == 0:
        #
        # Update model
        #
        self.total_updates += 1

        # convert to torch tensors
        batch_state = torch.FloatTensor(
            np.array(trajectory_states, dtype=float)
            ).to(device)
        batch_action = torch.LongTensor(
             np.array(trajectory_actions, dtype=int)
             ).unsqueeze(1).to(device)
        batch_reward = torch.FloatTensor(
             np.array(trajectory_rewards, dtype=float)
            ).unsqueeze(1).to(device)
        batch_done = torch.FloatTensor(
            np.array(trajectory_dones, dtype=bool)
            ).unsqueeze(1).to(device)

        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        #  TO DO: compute loss for REINFORCE
        # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        assert len(trajectory_actions) == self.batch_size

        action_logits, _ = self.policy_net(batch_state)
        logprobs = nn.functional.log_softmax(action_logits, dim=-1).gather(1, batch_action.long())
       
        loss = torch.tensor(0.0)

        last_index = -2
        episodes = batch_done.sum()
        discounted_reward = 0
        discounted_rewards = []
        for batch_item in range(self.batch_size - 1, -1, -1):
          if batch_done[batch_item]:
            discounted_rewards = torch.flip(torch.tensor(discounted_rewards), (0,)).to(device)
            trajectory_start = batch_item + 1
            trajectory_end = last_index + 1
            loss += (logprobs[trajectory_start:trajectory_end] * discounted_rewards).sum()
            discounted_reward = 0
            discounted_rewards = []
            last_index = batch_item

          discounted_reward = self.gamma * discounted_reward + batch_reward[batch_item]
          discounted_rewards.append(discounted_reward)

        discounted_rewards = torch.flip(torch.tensor(discounted_rewards), (0,)).to(device)
        trajectory_end = last_index +1
        loss += (logprobs[:trajectory_end] * discounted_rewards).sum()
        loss /= (episodes+1)
        loss = - loss

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        
        # log info about loss
        self.writer.add_scalar('loss', loss.item(), self.total_timesteps)

        # clear data
        trajectory_states = []
        trajectory_actions = []
        trajectory_rewards = []
        trajectory_dones = []

      # evaluate agent
      if self.total_timesteps % self.eval_every == 0:
          mean_rewards = self.eval(n_sim=5)
          self.writer.add_scalar(
              'eval_rewards', mean_rewards, self.total_timesteps)

      # check end of episode
      state = next_state
      if done:
        state = self.env.reset()
        self.total_episodes += 1
        self.writer.add_scalar(
                'episode_rewards', episode_reward, self.total_timesteps)
        self.writer.add_scalar(
                'episode', self.total_episodes, self.total_timesteps)
        episode_reward = 0.0

  def eval(self, n_sim=1, **kwargs):
    rewards = np.zeros(n_sim)
    eval_env = self.eval_env     # evaluation environment
    # Loop over number of simulations
    for sim in range(n_sim):
      state = eval_env.reset()
      done = False
      while not done:
        action = self.select_action(state, evaluation=True)
        next_state, reward, done, _ = eval_env.step(action)
        # update sum of rewards
        rewards[sim] += reward
        state = next_state
    return rewards.mean()

# %%
# # Training one instance of REINFORCE
# reinforce_agent = REINFORCEAgent(
#     env=(get_env, dict()),  # we can send (constructor, kwargs) as an env
#     **REINFORCE_PARAMS
# )
# reinforce_agent.fit(REINFORCE_TRAINING_TIMESTEPS)

#
# Training several instances using AgentManager
#
manager_kwargs = dict(
    agent_class=REINFORCEAgent,
    train_env=(get_env, dict()),
    eval_env=(get_env, dict()),
    fit_budget=REINFORCE_TRAINING_TIMESTEPS,
    n_fit=2,                # NOTE: You may increase this parameter (number of agents to train)
    parallelization='thread',
    seed=456,
    default_writer_kwargs=dict(maxlen=None,log_interval=10),
)

# REINFORCE
reinforce_manager = AgentManager(
    init_kwargs=REINFORCE_PARAMS,
    agent_name='REINFORCE',
    **manager_kwargs
)

# Train and append to previous managers
reinforce_manager.fit()
# Out:
# [WARNING] (Re)defining the following DefaultWriter parameters in AgentManager: ['maxlen', 'log_interval']
# [INFO] Running AgentManager fit() for REINFORCE...
# INFO: Making new env: CartPole-v0
# /usr/local/lib/python3.8/dist-packages/gym/envs/registration.py:505: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1` with the environment ID `CartPole-v1`.
#   logger.warn(
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# [INFO] [REINFORCE[worker: 0]] | max_global_step = 5547 | episode_rewards = 23.0 | dw_time_elapsed = 10.008313760999954 | episode = 219 | loss = 28110.927734375 | eval_rewards = 23.8 |
# [INFO] [REINFORCE[worker: 1]] | max_global_step = 5750 | episode_rewards = 69.0 | dw_time_elapsed = 10.101263567999922 | episode = 225 | loss = 6877.61328125 | eval_rewards = 27.2 |
# [INFO] [REINFORCE[worker: 0]] | max_global_step = 10768 | episode_rewards = 98.0 | dw_time_elapsed = 20.01168683500009 | episode = 364 | loss = 10400.4599609375 | eval_rewards = 41.8 |
# [INFO] [REINFORCE[worker: 1]] | max_global_step =
6 |
# [INFO] [REINFORCE[worker: 1]] | max_global_step = 47750 | episode_rewards = 109.0 | dw_time_elapsed = 132.27755314799992 | episode = 815 | loss = 130126.6484375 | eval_rewards = 136.2 |
# [INFO] ... trained!
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0
# INFO: Making new env: CartPole-v0

# %%
# Plots for REINFORCE
_ = plot_writer_data(reinforce_manager, tag='loss', title='Policy Loss')
_ = plot_writer_data(reinforce_manager, tag='episode_rewards', xtag='episode', title='Episode Rewards')
_ = plot_writer_data(reinforce_manager, tag='eval_rewards', title='Rewards (Evaluation)')
_ = plot_writer_data(reinforce_manager, tag='eval_rewards', title='Cumulative Rewards (Evaluation)', preprocess_func=np.cumsum)

# %% [markdown]
# #Part 3: Model Selection Using UCB

# %% [markdown]
# ## Question 3.1: Model Selection for RL
#
#
# In RL, it is hard to define in advance what is the best method to use and/or which architecture to choose for representing the policy or the value function.
#
# Normally, several algorithms are run in parallel and the final performance is used to select the best algorithm. Can we do this online?
#
# In this exercise, we present a simple idea for doing online model-selection by leveraging a multi-armed bandit (MAB) algorithm.
#
# You will start from a list containing one instance of each agent that you trained above (different versions of DQN and REINFORCE), and you'll adaptively allocate computational resources to train those algorithms for more timesteps.
#
# **Implement below the UCB algorithm such that, at reach round $t$:**
#
# * UCB selects the action $a_t$, which corresponds to one of the algorithms in the list;
# * You train the algorithm for a few timesteps;
# * UCB receives the reward $r_t$ which is equal to the Monte-Carlo policy evaluation of the chosen algorithm.
#
# The goal of this strategy is to allocate more computational resources to the algorithms that are yielding more rewards.

# %%
# Get one (pre-)trained agent from each manager
all_managers = all_dqn_managers + [reinforce_manager]
arms = [manager.get_agent_instances()[0] for manager in all_managers]
print(f"Arms/algorithms: {[alg.name for alg in arms]}")

# Select number of UCB rounds
UCB_N_ROUNDS = 200

# Number of training steps every time an agent is selected
N_STEPS_TO_TRAIN = 250

# Run UCB
all_episode_rewards = []
arm_counts = np.zeros(len(arms))
arm_cumulative_rewards = np.zeros(len(arms))
for tt in range(UCB_N_ROUNDS):
  if tt < len(arms):
    arm_index = tt
  else:
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    # TODO: Implement UCB arm selection
    # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    arm_index = 0
    mean_rewards = arm_cumulative_rewards / arm_counts
    ucb_bound = np.sqrt(np.log(2*tt) / arm_counts)
    arm_index = np.argmax(mean_rewards + ucb_bound)

  # train the selected algorithm for more timesteps
  arms[arm_index].fit(N_STEPS_TO_TRAIN)

  # evaluate arm
  episode_reward = arms[arm_index].eval()

  # update stats
  arm_counts[arm_index] += 1
  arm_cumulative_rewards[arm_index] += episode_reward

  # store reward
  all_episode_rewards.append(episode_reward)

  if (tt+1) % 10 == 0:
    print("-----------------------------------------------------------")
    print(f"UCB round {tt+1}, " 
          f"chosen algorithm: {arms[arm_index].name}, "
          f"eval reward = {episode_reward}.")
    print("-----------------------------------------------------------")
# Out:
# [INFO] [DQN[worker: 0]] | max_global_step = 10001 | episode_rewards = 24.0 | dw_time_elapsed = 1808.8819098360002 | episode = 435 | eval_rewards = 17.8 | loss = 0.0440637543797493 |
# Arms/algorithms: ['DQN', 'DoubleDQN', 'DuelingDQN', 'DoubleDuelingDQN', 'REINFORCE']
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 10001 | episode_rewards = 200.0 | dw_time_elapsed = 1573.391827805 | episode = 146 | eval_rewards = 200.0 | loss = 0.5908666849136353 |
# [INFO] [DuelingDQN[worker: 0]] | max_global_step = 10001 | episode_rewards = 42.0 | dw_time_elapsed = 1304.031931662 | episode = 325 | eval_rewards = 43.2 | loss = 0.06972721964120865 |
# [INFO] [DoubleDuelingDQN[worker: 0]] | max_global_step = 10001 | episode_rewards = 134.0 | dw_time_elapsed = 994.7982936819999 | episode = 167 | eval_rewards = 112.2 | loss = 0.7858257293701172 |
# [INFO] [REINFORCE[worker: 0]] | max_global_step = 50200 | episode_rewards = 200.0 | dw_time_elapsed = 625.2551273849999 | episode = 889 | loss = 657377.9375 | eval_rewards = 192.8 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 10939 | episode_rewards = 200.0 | dw_time_elapsed = 1583.3939472839998 | episode = 149 | eval_rewards = 200.0 | loss = 0.3260524868965149 |
# -----------------------------------------------------------
# UCB round 10, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 13116 | episode_rewards = 200.0 | dw_time_elapsed = 1593.3977682329996 | episode = 158 | eval_rewards = 200.0 | loss = 2.066401958465576 |
# -----------------------------------------------------------
# UCB round 20, chosen algorithm: DoubleDQN, eval reward = 180.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 15500 | episode_rewards = 200.0 | dw_time_elapsed = 1603.413070264 | episode = 168 | eval_rewards = 200.0 | loss = 0.14509522914886475 |
# -----------------------------------------------------------
# UCB round 30, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 17750 | episode_rewards = 200.0 | dw_time_elapsed = 1613.4180070479997 | episode = 177 | eval_rewards = 130.6 | loss = 0.20396269857883453 |
# -----------------------------------------------------------
# UCB round 40, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 19952 | episode_rewards = 200.0 | dw_time_elapsed = 1623.41839631 | episode = 191 | eval_rewards = 200.0 | loss = 2.923595905303955 |
# -----------------------------------------------------------
# UCB round 50, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 22238 | episode_rewards = 200.0 | dw_time_elapsed = 1633.420297441 | episode = 202 | eval_rewards = 113.0 | loss = 0.41579490900039673 |
# -----------------------------------------------------------
# UCB round 60, chosen algorithm: DoubleDQN, eval reward = 125.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 24501 | episode_rewards = 148.0 | dw_time_elapsed = 1643.4524036999996 | episode = 212 | eval_rewards = 169.2 | loss = 4.424885272979736 |
# -----------------------------------------------------------
# UCB round 70, chosen algorithm: DoubleDQN, eval reward = 130.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 26837 | episode_rewards = 165.0 | dw_time_elapsed = 1653.456304795 | episode = 223 | eval_rewards = 197.2 | loss = 0.1542256474494934 |
# -----------------------------------------------------------
# UCB round 80, chosen algorithm: DoubleDQN, eval reward = 66.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 29250 | episode_rewards = 200.0 | dw_time_elapsed = 1663.5143108949997 | episode = 234 | eval_rewards = 146.4 | loss = 0.12438315898180008 |
# -----------------------------------------------------------
# UCB round 90, chosen algorithm: DoubleDQN, eval reward = 147.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 31598 | episode_rewards = 136.0 | dw_time_elapsed = 1673.5168459379997 | episode = 244 | eval_rewards = 146.2 | loss = 4.363581657409668 |
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 33783 | episode_rewards = 163.0 | dw_time_elapsed = 1683.518411393 | episode = 254 | eval_rewards = 200.0 | loss = 7.0838942527771 |
# -----------------------------------------------------------
# UCB round 100, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 36093 | episode_rewards = 170.0 | dw_time_elapsed = 1693.521162989 | episode = 263 | eval_rewards = 200.0 | loss = 0.3307455778121948 |
# -----------------------------------------------------------
# UCB round 110, chosen algorithm: DoubleDQN, eval reward = 152.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 38250 | episode_rewards = 199.0 | dw_time_elapsed = 1703.563062919 | episode = 274 | eval_rewards = 163.0 | loss = 0.18766403198242188 |
# -----------------------------------------------------------
# UCB round 120, chosen algorithm: DoubleDQN, eval reward = 154.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 40750 | episode_rewards = 147.0 | dw_time_elapsed = 1713.5810284179997 | episode = 287 | eval_rewards = 120.2 | loss = 10.63455581665039 |
# -----------------------------------------------------------
# UCB round 130, chosen algorithm: DoubleDQN, eval reward = 126.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 42905 | episode_rewards = 117.0 | dw_time_elapsed = 1723.5852242259998 | episode = 300 | eval_rewards = 109.0 | loss = 3.526268243789673 |
# -----------------------------------------------------------
# UCB round 140, chosen algorithm: DoubleDQN, eval reward = 102.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 45138 | episode_rewards = 109.0 | dw_time_elapsed = 1733.5865568119998 | episode = 316 | eval_rewards = 110.0 | loss = 3.735640525817871 |
# -----------------------------------------------------------
# UCB round 150, chosen algorithm: DoubleDQN, eval reward = 98.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 47465 | episode_rewards = 119.0 | dw_time_elapsed = 1743.5871250179998 | episode = 334 | eval_rewards = 132.6 | loss = 1.9507923126220703 |
# -----------------------------------------------------------
# UCB round 160, chosen algorithm: DoubleDQN, eval reward = 119.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 49766 | episode_rewards = 115.0 | dw_time_elapsed = 1753.5896048119998 | episode = 351 | eval_rewards = 163.2 | loss = 0.6371158957481384 |
# -----------------------------------------------------------
# UCB round 170, chosen algorithm: DoubleDQN, eval reward = 190.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 52185 | episode_rewards = 154.0 | dw_time_elapsed = 1763.590088985 | episode = 365 | eval_rewards = 70.6 | loss = 0.724907398223877 |
# -----------------------------------------------------------
# UCB round 180, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 54555 | episode_rewards = 200.0 | dw_time_elapsed = 1773.5908777169998 | episode = 377 | eval_rewards = 121.6 | loss = 3.8298563957214355 |
# -----------------------------------------------------------
# UCB round 190, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------
# [INFO] [DoubleDQN[worker: 0]] | max_global_step = 57036 | episode_rewards = 200.0 | dw_time_elapsed = 1783.5913716209998 | episode = 390 | eval_rewards = 200.0 | loss = 10.184395790100098 |
# -----------------------------------------------------------
# UCB round 200, chosen algorithm: DoubleDQN, eval reward = 200.0.
# -----------------------------------------------------------

# %%
# Print stats
print(f"Arms: {[alg.name for alg in arms]}")
print(f"Counts: {arm_counts}")
print(f"Mean arm rewards: {arm_cumulative_rewards/arm_counts}")

# Plot rewards and regret
all_episode_rewards = np.array(all_episode_rewards)
plt.figure()
plt.plot(np.cumsum(all_episode_rewards))
plt.title("Cumulative Rewards")
plt.figure()
plt.plot(np.cumsum(200.0 - all_episode_rewards))  # maximum reward in CartPole-v0 is 200.0
plt.title("Regret")
plt.show()
# Out:
# Arms: ['DQN', 'DoubleDQN', 'DuelingDQN', 'DoubleDuelingDQN', 'REINFORCE']
# Counts: [  1. 196.   1.   1.   1.]
# Mean arm rewards: [ 16.         152.46428571  39.         107.         134.        ]

# %% [markdown]
# ## Question 3.2: Is UCB well-suited for online model-selection?
#
# At every round of UCB, one algorithm is selected and trained for a few timesteps. Does this break any assumption made by the UCB algorithm? If so, how would you handle this issue?

# %% [markdown]
# The assumption that is broken is the one that says that the rewards have the same distribution. However in UCB when we select an arm we're modifying its average so its distribution is not the same anymore.
